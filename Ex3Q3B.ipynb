# %%
# Data input
N = ...
eA = ...
eB = ...
cA = ...
cB = ...

# %%
gcd(eA,eB) #Judge whether eA and eB are mutually prime
# Out:
# 1

# %%
a = xgcd(eA,eB)

s1 = a [1] #get s1 value from the second element in the result of xgcd()
s2 = a [2] #get s2 value from the last element in the result of xgcd()

# %%
eA * s1 + eB * s2 == 1 #Verify that the required s1, s2 are correct
# Out:
# True

# %%
m = mod(power_mod(cA,s1,N) * power_mod(cB,s2,N), N)
m
# Calculate plaintext
# Out:
# ...
